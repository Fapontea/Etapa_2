# %%
import pandas as pd

bd = pd.read_csv('data.csv')
bd.head()
# Out:
#    metro  precio
# 0      5     375
# 1     15     487
# 2     20     450
# 3     25     500

# %%
import pandas as pd
import numpy as np
import seaborn as sns

bd = pd.read_csv('data.csv')
sns.regplot(x='metro', y='precio', data= bd)
# Out:
# <Axes: xlabel='metro', ylabel='precio'>
